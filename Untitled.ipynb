# %%
import csv
import pandas as pd
import random
import numpy as np


bike_file = open('citibike_data.csv', 'a')
bike_file.write(open("raw_bike_files/JC-201710-citibike-tripdata.csv").read())
bike_file.write(open("raw_bike_files/JC-201711-citibike-tripdata.csv").read())
bike_file.write(open("raw_bike_files/JC-201712-citibike-tripdata.csv").read())
bike_file.write(open("raw_bike_files/JC-201801-citibike-tripdata.csv").read())
bike_file.write(open("raw_bike_files/JC-201802-citibike-tripdata.csv").read())
bike_file.write(open("raw_bike_files/JC-201803-citibike-tripdata.csv").read())
bike_file.write(open("raw_bike_files/JC-201804-citibike-tripdata.csv").read())
bike_file.write(open("raw_bike_files/JC-201805-citibike-tripdata.csv").read())
bike_file.write(open("raw_bike_files/JC-201806-citibike-tripdata.csv").read())
bike_file.write(open("raw_bike_files/JC-201807-citibike-tripdata.csv").read())
bike_file.write(open("raw_bike_files/JC-201808-citibike-tripdata.csv").read())
bike_file.write(open("raw_bike_files/JC-201809-citibike-tripdata.csv").read())
bike_file.close()

# %%
bike_data = pd.read_csv("citibike_data.csv", sep=',', error_bad_lines=False, index_col=False, dtype='unicode')
bike_data.count()
# Out:
# tripduration               344049
# starttime                  344049
# stoptime                   344049
# start station id           344049
# start station name         344049
# start station latitude     344049
# start station longitude    344049
# end station id             344049
# end station name           344049
# end station latitude       344049
# end station longitude      344049
# bikeid                     344049
# usertype                   344049
# birth year                 340594
# gender                     344049
# dtype: int64

# %%
citibike_df = pd.read_csv('citibike_data.csv')
# Out:
# /anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (0,3,5,6,7,9,10,11,13,14) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
citibike_df.isnull().sum()
# Out:
# tripduration                  0
# starttime                     0
# stoptime                      0
# start station id              0
# start station name            0
# start station latitude        0
# start station longitude       0
# end station id                0
# end station name              0
# end station latitude          0
# end station longitude         0
# bikeid                        0
# usertype                      0
# birth year                 3455
# gender                        0
# dtype: int64

# %%
citibike_df.dropna()
# Out:
#        tripduration                 starttime                  stoptime  \
# 0               410       2017-10-01 00:03:08       2017-10-01 00:09:59
# 1               412       2017-10-01 00:03:13       2017-10-01 00:10:06
# 2               274       2017-10-01 00:24:07       2017-10-01 00:28:42
# 3              2198       2017-10-01 00:31:03       2017-10-01 01:07:42
# 4               166       2017-10-01 00:34:09       2017-10-01 00:36:56
# 5               129       2017-10-01 00:39:15       2017-10-01 00:41:24
# 6               315       2017-10-01 00:46:42       2017-10-01 00:51:57
# 7               301       2017-10-01 00:47:02       2017-10-01 00:52:03
# 8               170       2017-10-01 00:48:40       2017-10-01 00:51:30
# 9               214       2017-10-01 00:54:54       2017-10-01 00:58:29
# 10             1142       2017-10-01 01:04:55       2017-10-01 01:23:58
# 11              433       2017-10-01 01:13:55       2017-10-01 01:21:08
# ...

# %%
citibike_df=citibike_df.dropna(axis=1,how='any')

# %%
citibike_df.isnull().sum()
# Out:
# tripduration               0
# starttime                  0
# stoptime                   0
# start station id           0
# start station name         0
# start station latitude     0
# start station longitude    0
# end station id             0
# end station name           0
# end station latitude       0
# end station longitude      0
# bikeid                     0
# usertype                   0
# gender                     0
# dtype: int64

# %%
citibike_df.count()
# Out:
# tripduration               344049
# starttime                  344049
# stoptime                   344049
# start station id           344049
# start station name         344049
# start station latitude     344049
# start station longitude    344049
# end station id             344049
# end station name           344049
# end station latitude       344049
# end station longitude      344049
# bikeid                     344049
# usertype                   344049
# gender                     344049
# dtype: int64
